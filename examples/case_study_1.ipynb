# %% [markdown]
# ## **Case study 1: Techno-economic comparison of hydrogen production pathways**
# <p style='text-align: justify;'>Hydrogen (H₂) production is a cornerstone of a low-carbon energy system, with technologies such as <b>steam methane reforming (SMR)</b>, <b>methane pyrolysis (MP)</b>, and <b>renewable-powered water electrolysis (WE)</b> offering different trade-offs in efficiency, cost, and environmental impact. Their varied energy demands, carbon intensities, and capital requirements make rigorous techno-economic assessment (TEA) essential for identifying scalable, cost-effective pathways.</p>
#
# <p style='text-align: justify;'>In this case study, we apply <b>OpenPyTEA</b> to consistently evaluate the technical and economic performance of SMR, MP, and WE. The analysis covers capital cost (CAPEX), operating cost (OPEX), levelized cost of H₂ (LCOH), sensitivity analysis and Monte Carlo–based uncertainty analysis. This demonstrates how <b>OpenPyTEA</b> streamlines scenario setup, parameter management, and results analysis, enabling transparent and reproducible comparison across H₂ production technologies.</p>
#
# Let's start first by importing <b>OpenPyTEA</b>:

# %%
from openpytea import *

# %% [markdown]
# To ensure a consistent comparison across all processes, we now define the economic assumptions applied to each case. All processes are assumed to produce 50 tonnes of H₂ per day, with a hydrogen price of $5.5 per kg.

# %%
# Location and project assumptions
country           = 'United States'  # USA-Gulf Coast as an example
region            = 'Gulf Coast'
interest_rate     = 0.09
project_lifetime  = 30
plant_utilization = 0.95
tax_rate = 0.25    

# H₂ production
h2_prod  = 50_000  # Daily H₂ production in kg (50 tonnes/day)
h2_price = 5       # US$/kg

# Labor — operator hourly rate for USA-Gulf Coast (US$/h)
# fmt: value,  std,  max,  min
operator_rate, operator_std, operator_max, operator_min = 38.11, 10, 50, 25

# Utilities and raw materials — (value, std, max, min)
elecs_price,      elecs_std,      elecs_max,      elecs_min      =  0.05,       0.03,  3,      0.01   # Electricity   (US$/kWh)
nat_gas_price,    nat_gas_std,    nat_gas_max,    nat_gas_min    =  0.4,        0.25,  5,      0      # Natural gas   (US$/kg)
cool_water_price, cool_water_std, cool_water_max, cool_water_min =  2.4592e-4,  1e-4,  4e-4,   1e-5   # Cooling water (US$/MJ)
co2_tax,          co2_std,        co2_max,        co2_min        =  0.075,      0.02,  0.15,   0      # CO₂ tax       (US$/kg CO₂)

# %% [markdown]
# The following sections present the process design and economic assessment for each H₂ production pathway. Process parameters for SMR and MP shown in the respective process flow diagrams are derived from Aspen Plus simulations. The corresponding simulation files are provided in the folder `aspen_plus_sims`. For WE, we based the capital costs and operating energy consumption from U.S. Department of Energy TEA report for H₂ production cost with alkaline electrolysis [1].

# %% [markdown]
# ---------------------
# ### Steam Methane Reforming (SMR)
#
# <p style='text-align: justify;'>SMR is the most established and widely used H₂ production technology, supplying over half of global H₂ demand. In SMR, methane reacts with high-temperature steam over a nickel catalyst to form synthesis gas, which is then processed in a water–gas shift reactor to increase H₂ yield. While SMR is efficient and relatively low-cost, it is also carbon dioxide (CO₂)-intensive due to CO₂ generated in both the reforming reaction and furnace combustion. CO₂ capture can reduce emissions but adds capital and operating costs, underscoring the need for TEA to evaluate its long-term competitiveness.</p>
#
# <p style='text-align: justify;'>This SMR case study is adapted from the flow sheet in Boyano et al. [2], while the kinetic models follow Xu & Froment [3] and Choi & Stenger [4] for SMR and water–gas shift (WGS) reactions, respectively. The SMR reaction takes place in a catalytic reactor that operates isothermally at 700 °C, followed by the WGS reaction in high- and low-temperature WGS reactors. Hydrogen gas is separated via pressure-swing adsorption, while the remaining gases are combusted to supply heat for the SMR process (supplemented by additional methane feed). Steam for the reaction is generated by heating water using heat recovered from the WGS reactors and methane combustion. </p>
#
# <p style='text-align: justify;'>The following figure presents the MP process flow diagram, and the accompanying table summarizes the equipment sizing:</p>
#
# ![case_study_2-figure_1](img/CS_2-Fig_1.png) **<p style='text-align: justify; font-size: 90%;'>Figure 1.** Process flow diagram of the SMR system. The diagram illustrates compression and mixing of the methane feed, preheating in HEATER-1, and catalytic reforming in the SMR reactor. The reactor effluent is cooled and sent through high-temperature (WGS-HT) and low-temperature (WGS-LT) water–gas shift reactors to increase H₂ yield. Heat exchangers (HX-1, HX-2, HX-3) recover energy for steam generation and feed preheating. Hydrogen is purified via pressure-swing adsorption (PSA), while the off-gas is routed to a furnace for combustion along with supplemental fuel. Combustion heat is used to support endothermic SMR reactions and additional heating duties within the process.</p>
#
# <center>
# <p style="font-size: 90%;"><b>Table 1.</b> Details and sizing of process equipment in the SMR plant. </p>
# <span style="font-size: 14px">
#
# | **Name**           | **Process Type** | **Equipment Category**        | **Equipment Type**        | **Sizing Parameter** | **Unit** | **Material**         |
# |--------------------|------------------|-------------------------------|---------------------------|----------------------|----------|----------------------|
# | COMP-1             | Fluids           | Compressors, fans, & blowers  | Compressor, centrifugal   | 945                  | kW       | Carbon steel         |
# | COMP-2             | Fluids           | Compressors, fans, & blowers  | Compressor, centrifugal   | 491                  | kW       | Carbon steel         |
# | MTR-1<sup>a</sup>       | Electrical       | Motors & generators           | Totally enclosed motor    | 945/0.9              | kW       | Carbon steel         |
# | MTR-2<sup>a</sup>       | Electrical       | Motors & generators           | Totally enclosed motor    | 491/0.9              | kW       | Carbon steel         |
# | HX-1               | Fluids           | Heat Exchangers               | U-tube shell & tube       | 31.87                | m²       | 304 stainless steel  |
# | HX-2               | Fluids           | Heat Exchangers               | U-tube shell & tube       | 22.74                | m²       | 304 stainless steel  |
# | HX-3               | Fluids           | Heat Exchangers               | U-tube shell & tube       | 107.19               | m²       | 304 stainless steel  |
# | COOLER             | Fluids           | Heat Exchangers               | U-tube shell & tube       | 191.47               | m²       | Carbon steel         |
# | SMR-REACTOR        | Fluids           | Reactors                      | Tubular fixed bed         | 91.56                | kg       | 304 stainless steel  |
# | WGS-HT-REACTOR     | Fluids           | Reactors                      | Tubular fixed bed         | 376.54               | kg       | 304 stainless steel  |
# | WGS-LT-REACTOR     | Fluids           | Reactors                      | Tubular fixed bed         | 3822.92              | kg       | 304 stainless steel  |
# | FURNACE            | Fluids           | Boilers, heaters, & furnaces  | Furnace, cylindrical      | 33.26                | MW       | 304 stainless steel  |
# | PUMP               | Fluids           | Pumps                         | Single-stage centrifugal  | 5.16                 | L/s      | Carbon steel         |
# | PSA                | Fluids           | Gas separation                | Pressure-swing adsorber   | 1023.49              | kmol/h   | Carbon steel         |
#
# <sup>a</sup>Electric motors are added for driving the compressors with 90% electrical-to-mechanical efficiency.
# </span></center>
#
#
# Now, we create the SMR process equipment objects:

# %%
# First, we create the compressor and electric-motor (for driving the compressors) objects.
# We choose here the centrifugal type for both compressors.
comp_1_pwr = 945  # kW
comp_2_pwr = 491  # kW
comp_1 = Equipment('COMP-1', comp_1_pwr, "Fluids", "Compressors, fans, & blowers", "Compressor, centrifugal", "Carbon steel")
comp_2 = Equipment('COMP-2', comp_2_pwr, "Fluids", "Compressors, fans, & blowers", "Compressor, centrifugal", "Carbon steel")

# When the electric motor drives the compressors there are some losses involved. Here we assumed 90% efficiency.
mtr_eff   = 0.9
mtr_1_pwr = comp_1_pwr / mtr_eff
mtr_2_pwr = comp_2_pwr / mtr_eff
mtr_1 = Equipment('MTR-1', mtr_1_pwr, "Electrical", "Motors & generators", "Totally enclosed motor", "Carbon steel")
mtr_2 = Equipment('MTR-2', mtr_2_pwr, "Electrical", "Motors & generators", "Totally enclosed motor", "Carbon steel")

# Next, we create heat exchanger objects, modeled shell & tube.
hx_1   = Equipment('HX-1',   31.87,   "Fluids", "Heat Exchangers", "U-tube shell & tube", "304 stainless steel")
hx_2   = Equipment('HX-2',   22.74,   "Fluids", "Heat Exchangers", "U-tube shell & tube", "304 stainless steel")
hx_3   = Equipment('HX-3',   107.19,  "Fluids", "Heat Exchangers", "U-tube shell & tube", "304 stainless steel")
cooler = Equipment('COOLER',  191.47, "Fluids", "Heat Exchangers", "U-tube shell & tube", "Carbon steel")

# Now we create the reactor objects for the SMR and WGS reactors.
smr_reactor    = Equipment('SMR-REACTOR',    160,     "Fluids", "Reactors", "Tubular fixed bed", "304 stainless steel")
wgs_ht_reactor = Equipment('WGS-HT-REACTOR', 376.54,  "Fluids", "Reactors", "Tubular fixed bed", "304 stainless steel")
wgs_lt_reactor = Equipment('WGS-LT-REACTOR', 3822.92, "Fluids", "Reactors", "Tubular fixed bed", "304 stainless steel")

# Now for the remaining equipment.
furnace = Equipment('FURNACE', 33.26,   "Fluids", "Boilers, heaters, & furnaces", "Furnace, cylindrical",     "304 stainless steel")
pump    = Equipment('PUMP',    5.16,    "Fluids", "Pumps",                        "Single-stage centrifugal", "Carbon steel")
psa     = Equipment('PSA',     1023.49, "Fluids", "Gas separation",               "Pressure-swing adsorber",  "Carbon steel")

# We can now create a list of the equipment for the SMR process.
smr_equipment = [
    comp_1, mtr_1,
    comp_2, mtr_2,
    hx_1, hx_2, hx_3, cooler,
    smr_reactor, wgs_ht_reactor, wgs_lt_reactor,
    furnace, pump, psa
]

# %% [markdown]
# Note that, here, <b>OpenPyTEA</b> estimates the purchased cost of the above process components through look-up in the cost-correlation database based on the specified equipment category and type. If multiple cost correlations exist for the same equipment category and type, <b>OpenPyTEA</b> selects the first entry in the database list (please refer to [`walkthrough.ipynb` ](https://github.com/pbtamarona/OpenPyTEA/blob/main/walkthrough.ipynb) for more details).
#
# Next, we create the SMR plant object:

# %%
# Configuration for the SMR plant
config = {
    'plant_name'          : 'Steam Reforming',
    'process_type'        : 'Fluids',        # Since there are only fluids, we choose 'Fluids'
    'country'             : country,
    'region'              : region,
    'equipment'           : smr_equipment,   # This the list of equipment for the SMR process
    'interest_rate'       : interest_rate,   # Base economic assumptions
    'project_lifetime'    : project_lifetime,
    'plant_utilization'   : plant_utilization,
    'tax_rate'            : tax_rate,
    'operator_hourly_rate': {
        'rate': operator_rate, 'std': operator_std, 'max': operator_max, 'min': operator_min
    },
    'plant_products': {  # Here we define the products and/or inputs of the plant
        'hydrogen': {
            'production': h2_prod,   # Daily production in kg/day
            'price'     : h2_price,  # Price of hydrogen, in US$/kg
        }
    },
    'variable_opex_inputs': {  # For the variable opex inputs, the consumption is always based on daily consumption
        'electricity': {
            'consumption': (mtr_1_pwr + mtr_2_pwr)*24,
            'price': elecs_price, 'std': elecs_std, 'max': elecs_max, 'min': elecs_min
        },
        'methane_feed': {  # We assume the methane feed is natural gas (used as the main feedstock for the process & as heating fuel)
            'consumption': (5139+4025)*24, # Methane feed in kg/day (the value comes from the Aspen Plus simulation)
            'price': nat_gas_price, 'std': nat_gas_std, 'max': nat_gas_max, 'min': nat_gas_min
        },
        'cooling_water': {  
            'consumption': 20222.67*24, # Cooling duties in Cooler (the value comes from the Aspen Plus simulation)
            'price': cool_water_price, 'std': cool_water_std, 'max': cool_water_max, 'min': cool_water_min
        },
        'CO$_2$_tax': { 
            'consumption': 25124.64*24, # CO₂ emissions in kg/day (the value comes from the Aspen Plus simulation)
            'price': co2_tax, 'std': co2_std, 'max': co2_max, 'min': co2_min
        },
    },
}
smr_plant = Plant(config)  # Create the process plant object. Here we name it smr_plant.

# %% [markdown]
# The following lines calculate for the CAPEX, OPEX and LCOH of the SMR plant:

# %%
smr_plant.calculate_fixed_capital(print_results=True)   # Calculate the FCI and print the details
smr_plant.calculate_variable_opex(print_results=True)   # Calculate the Variable OPEX and print the details
smr_plant.calculate_levelized_cost(print_results=True)  # Calculate the LCOH and print the details
# Out:
# Capital cost estimation
# ===================================
# ISBL: 29,145,338.16 USD
# OSBL: 8,743,601.45 USD
# Design and engineering: 11,366,681.88 USD
# Contingency: 3,788,893.96 USD
# ===================================
# Fixed capital investment: 53,044,515.46 USD
# Variable production costs estimation
# ===================================
#   - Electricity: 663,910.67 USD per year
#   - Methane feed: 30,505,123.20 USD per year
#   - Cooling water: 41,386.63 USD per year
#   - Co$ 2$ tax: 15,681,544.06 USD per year
# ===================================
# Total Variable OPEX: 46,891,964.55USD per year
# Levelized cost: 3.918 USD/unit

# %% [markdown]
# ---------------
#
# ### Methane Pyrolysis (MP)
# <p style='text-align: justify;'>MP produces H₂ without direct CO₂ emissions by thermally splitting methane into H₂ and solid carbon. Depending on the heat source—such as plasma, molten metal, or non-catalytic reactors—the process exhibits different efficiencies and scale-up challenges. When powered by renewable or waste heat, MP offers a low-carbon H₂ pathway, though its economics depend heavily on reactor design, heat supply, and the management or valorization of the solid carbon by-product.</p>
#
# <p style='text-align: justify;'>This case study follows the non-catalytic MP process of Keipi et al. [5,6], using a regenerative heat-exchanger reactor (RHER). Methane is cracked at 1300 K, producing H₂ while depositing solid carbon. In addition to external heating, hot product gases heat a circulating bed of ceramic beads, which in turn preheat the incoming methane. Most carbon forms on the bead surfaces and is removed through the circulation loop. For simplicity, detailed modeling of the bed-material loop and downstream carbon-handling units is omitted.</p>
#
# <p style='text-align: justify;'>The following figure presents the MP process flow diagram, and the accompanying table summarizes the equipment sizing:</p>
#
# ![case_study_2-figure_2](img/CS_2-Fig_2.png)
# **<p style='text-align: justify; font-size: 90%;'>Figure 2.** Process flow diagram of a MP system producing H₂ and solid carbon. Fresh methane feed is compressed (COMP-1) and preheated in heat exchanger (HX-1) before entering the moving bed reactor, where endothermic pyrolysis occurs and using a heated bed material circulated to separate the gas-solid products. Combustion of a CH₄–air stream (COMP-3) supplies the thermal energy, and the resulting flue gas exits the system. Carbon particulates are separated in a cyclone and routed to a dedicated carbon-bed material separation unit for solid carbon recovery. The gas products from the reactor is cooled (COOLER-1, COOLER-2), compressed (COMP-2), and purified in a Pressure Swing Adsorption (PSA) unit to produce a H₂ stream, while unreacted methane is recycled to the reactor.</p>
#
#
# <center>
# <p style="font-size: 90%;"><b>Table 2.</b> Details and sizing of process equipment in the MP plant </p>
# <span style="font-size: 14px">
#
# | **Name**   | **Process Type** | **Equipment Category**        | **Equipment Type**        | **Sizing Parameter** | **Unit** | **Material**        |
# |------------|------------------|-------------------------------|---------------------------|----------------------|----------|---------------------|
# | COMP-1     | Fluids           | Compressors, fans, & blowers  | Compressor, centrifugal   | 205                  | kW       | Carbon steel        |
# | COMP-2     | Fluids           | Compressors, fans, & blowers  | Compressor, centrifugal   | 2993                 | kW       | Carbon steel        |
# | COMP-3     | Fluids           | Compressors, fans, & blowers  | Compressor, centrifugal   | 363                  | kW       | Carbon steel        |
# | MTR-1<sup>a</sup>       | Electrical       | Motors & generators           | Totally enclosed motor    | 205/0.9              | kW       | Carbon steel         |
# | MTR-2<sup>a</sup>       | Electrical       | Motors & generators           | Totally enclosed motor    | 2993/0.9              | kW       | Carbon steel         |
# | MTR-3<sup>a</sup>       | Electrical       | Motors & generators           | Totally enclosed motor    | 363/0.9              | kW       | Carbon steel         |
# | HX-1       | Fluids           | Heat Exchangers               | U-tube shell & tube       | 28.37                | m²       | 316 stainless steel |
# | COOLER-1   | Fluids           | Heat Exchangers               | U-tube shell & tube       | 41.85                | m²       | Carbon steel        |
# | COOLER-2   | Fluids           | Heat Exchangers               | U-tube shell & tube       | 26.21                | m²       | Carbon steel        |
# | REACTOR    | Mixed            | Reactors                      | Indirect fluidized-bed    | 147.26               | m³       | 316 stainless steel |
# | FURNACE    | Fluids           | Boilers, heaters, & furnaces  | Pyrolysis furnace         | 22608                | kW       | 316 stainless steel |
# | CYCLONE    | Mixed            | Dust collectors               | Gas multi-cyclone         | 36.70                | m³/s     | 316 stainless steel |
# | PSA        | Fluids           | Gas separation                | Pressure-swing adsorber   | 1017.98              | kmol/h   | Carbon steel        |
#
# <sup>a</sup>Electric motors are added for driving the compressors with 90% electrical-to-mechanical efficiency.
# </span></center>
#
# As in the previous case study, we first create the process-equipment objects:

# %%
# First, we create the compressor and electric-motor (for driving the compressors) objects.
# We choose here the centrifugal type for both compressors, as in the SMR case.
comp_1_pwr = 205   # kW
comp_2_pwr = 2993  # kW
comp_3_pwr = 363   # kW
comp_1 = Equipment('COMP-1', comp_1_pwr, "Fluids", "Compressors, fans, & blowers", "Compressor, centrifugal", "Carbon steel")
comp_2 = Equipment('COMP-2', comp_2_pwr, "Fluids", "Compressors, fans, & blowers", "Compressor, centrifugal", "Carbon steel")
comp_3 = Equipment('COMP-3', comp_3_pwr, "Fluids", "Compressors, fans, & blowers", "Compressor, centrifugal", "Carbon steel")

# When the electric motor drives the compressors there are some losses involved. Here we assumed 90% efficiency.
mtr_eff   = 0.9
mtr_1_pwr = comp_1_pwr / mtr_eff
mtr_2_pwr = comp_2_pwr / mtr_eff
mtr_3_pwr = comp_3_pwr / mtr_eff
mtr_1 = Equipment('MTR-1', mtr_1_pwr, "Electrical", "Motors & generators", "Totally enclosed motor", "Carbon steel")
mtr_2 = Equipment('MTR-2', mtr_2_pwr, "Electrical", "Motors & generators", "Totally enclosed motor", "Carbon steel")
mtr_3 = Equipment('MTR-3', mtr_3_pwr, "Electrical", "Motors & generators", "Totally enclosed motor", "Carbon steel")

# Next, we create the shell & tube heat exchanger objects.
hx_1     = Equipment('HX-1',     28.37, "Fluids", "Heat Exchangers", "U-tube shell & tube", "316 stainless steel")
cooler_1 = Equipment('COOLER-1', 41.85, "Fluids", "Heat Exchangers", "U-tube shell & tube", "Carbon steel")
cooler_2 = Equipment('COOLER-2', 26.21, "Fluids", "Heat Exchangers", "U-tube shell & tube", "Carbon steel")

# Now we create the reactor, furnace, cyclone and PSA objects.
reactor = Equipment('REACTOR', 147.26,  "Mixed",  "Reactors",                     "Indirect fluidized-bed",  "316 stainless steel")
furnace = Equipment('FURNACE', 22608,   "Fluids", "Boilers, heaters, & furnaces", "Pyrolysis furnace",       "316 stainless steel")
cyclone = Equipment('CYCLONE', 36.70,   "Mixed",  "Dust collectors",              "Gas multi-cyclone",       "316 stainless steel")
psa     = Equipment('PSA',     1017.98, "Fluids", "Gas separation",               "Pressure-swing adsorber", "Carbon steel")

# We can now create a list of the equipment for the MP process.
mp_equipment = [
    comp_1, mtr_1,
    comp_2, mtr_2,
    comp_3, mtr_3,
    hx_1, cooler_1, cooler_2,
    reactor, furnace,
    cyclone, psa
]

# %% [markdown]
# As with the SMR equipment, here, the purchased costs of the process components are estimated through look-up in the cost-correlation database based on the specified equipment category and type.
#
# Next, we create the MP plant object:

# %%
# Configuration for the MP plant
config = {
    'plant_name'          : 'Methane Pyrolysis',
    'process_type'        : 'Mixed',         # Since there are both fluids and solids involved, we choose 'Mixed'
    'country'             : country,
    'region'              : region,
    'equipment'           : mp_equipment,    # This the list of equipment for the MP process
    'interest_rate'       : interest_rate,   # Base economic assumptions
    'project_lifetime'    : project_lifetime,
    'plant_utilization'   : plant_utilization,
    'tax_rate'            : tax_rate,
    'operator_hourly_rate': {
        'rate': operator_rate, 'std': operator_std, 'max': operator_max, 'min': operator_min
    },
    'plant_products': {  # Here we define the products and/or inputs of the plant
        'hydrogen': {
            'production': h2_prod,   # Daily production in kg/day
            'price'     : h2_price,  # Price of hydrogen, in US$/kg
        },
        'solid_carbon': { # We assume that 50% of the produced solid carbon can be sold as a co-product
            'production': 6100*0.5*24,  # Daily production in kg/day
            'price': 1, 'std': 0.4, 'max': 3, 'min': 0
        },
    },
    'variable_opex_inputs': {  # For the variable opex inputs, the consumption is always based on daily consumption
        'electricity': {
            'consumption': (mtr_1_pwr + mtr_2_pwr + mtr_3_pwr)*24,
            'price': elecs_price, 'std': elecs_std, 'max': elecs_max, 'min': elecs_min
        },
        'methane_feed': {  # We assume the methane feed is natural gas (used as the main feedstock for the process & as heating fuel)
            'consumption': (8184+3775)*24, # Methane feed in kg/day (the value comes from the Aspen Plus simulation)
            'price': nat_gas_price, 'std': nat_gas_std, 'max': nat_gas_max, 'min': nat_gas_min
        },
        'cooling_water': {  # Cooling duties in Cooler-1, Cooler-2 and intercoolers (the value comes from the Aspen Plus simulation)
            'consumption': (12816.41+1313.09+9443.57)*24,
            'price': cool_water_price, 'std': cool_water_std, 'max': cool_water_max, 'min': cool_water_min
        },
        'CO$_2$_tax': {
            'consumption': 10357*24, # CO₂ emissions in kg/day (the value comes from the Aspen Plus simulation)
            'price': co2_tax, 'std': co2_std, 'max': co2_max, 'min': co2_min
        },
        'carbon_disposal_fee': {  # The remaining 50% of solid carbon must be disposed of at a cost
            'consumption': 6100*0.5*24,
            'price': 0.5, 'std': 0.4, 'max': 1, 'min': 0
        },
    },
}
mp_plant = Plant(config)  # Create the process plant object. Here we name it mp_plant.

# %% [markdown]
# CAPEX, OPEX and LCOH calculation:

# %%
mp_plant.calculate_cash_flow(print_results=True)   # Calculate the FCI and print the details
# Out:
# <style type="text/css">
# </style>
# <table id="T_57662">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57662_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_57662_level0_col1" class="col_heading level0 col1" >Capital cost [USD]</th>
#       <th id="T_57662_level0_col2" class="col_heading level0 col2" >Revenue [USD]</th>
#       <th id="T_57662_level0_col3" class="col_heading level0 col3" >Cash cost [USD]</th>
#       <th id="T_57662_level0_col4" class="col_heading level0 col4" >Gross profit [USD]</th>
#       <th id="T_57662_level0_col5" class="col_heading level0 col5" >Depreciation [USD]</th>
#       <th id="T_57662_level0_col6" class="col_heading level0 col6" >Taxable income [USD]</th>
#       <th id="T_57662_level0_col7" class="col_heading level0 col7" >Tax paid [USD]</th>
#       <th id="T_57662_level0_col8" class="col_heading level0 col8" >Cash flow [USD]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57662_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_57662_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_57662_row0_col1" class="data row0 col1" >22,829,044.57</td>
#       <td id="T_57662_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_57662_row0_col3" class="data row0 col3" >23,984,653.09</td>
#       <td id="T_57662_row0_col4" class="data row0 col4" >-23,984,653.09</td>
#       <td id="T_57662_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_57662_row0_col6" class="data row0 col6" >-23,984,653.09</td>
#       <td id="T_57662_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_57662_row0_col8" class="data row0 col8" >-46,813,697.66</td>
#     </tr>
#     <tr>
#       <th id="T_57662_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_57662_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_57662_row1_col1" class="data row1 col1" >45,658,089.14</td>
#       <td id="T_57662_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_57662_row1_col3" class="data row1 col3" >23,984,653.09</td>
#       <td id="T_57662_row1_col4" class="data row1 col4" >-23,984,653.09</td>
#       <td id="T_57662_row1_col5" class="data row1 col5" >0.00</td>
#       <td id="T_57662_row1_col6" class="data row1 col6" >-23,984,653.09</td>
#       <td id="T_57662_row1_col7" class="data row1 col7" >0.00</td>
#       <td id="T_57662_row1_col8" class="data row1 col8" >-69,642,742.24</td>
#     </tr>
#     <tr>
#       <th id="T_57662_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_57662_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_57662_row2_col1" class="data row2 col1" >19,024,203.81</td>
#       <td id="T_57662_row2_col2" class="data row2 col2" >44,827,840.00</td>
#       <td id="T_57662_row2_col3" class="data row2 col3" >48,248,294.34</td>
#       <td id="T_57662_row2_col4" class="data row2 col4" >-3,420,454.34</td>
#       <td id="T_57662_row2_col5" class="data row2 col5" >5,073,121.02</td>
#       <td id="T_57662_row2_col6" class="data row2 col6" >-8,493,575.36</td>
#       <td id="T_57662_row2_col7" class="data row2 col7" >0.00</td>
#       <td id="T_57662_row2_col8" class="data row2 col8" >-22,444,658.15</td>
#     </tr>
#     <tr>
#       <th id="T_57662_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_57662_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_57662_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_57662_row3_col2" class="data row3 col2" >89,655,680.00</td>
#       <td id="T_57662_row3_col3" class="data row3 col3" >72,511,935.59</td>
#       <td id="T_57662_row3_col4" class="data row3 col4" >17,143,744.41</td>
#       <td id="T_57662_row3_col5" class="data row3 col5" >5,073,121.02</td>
#       <td id="T_57662_row3_col6" class="data row3 col6" >12,070,623.39</td>
#       <td id="T_57662_row3_col7" class="data row3 col7" >0.00</td>
#       <td id="T_57662_row3_col8" class="data row3 col8" >17,143,744.41</td>
#     </tr>
#     <tr>
#       <th id="T_57662_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_57662_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_57662_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_57662_row4_col2" class="data row4 col2" >112,069,600.00</td>
#       <td id="T_57662_row4_col3" class="data row4 col3" >84,643,756.22</td>
#       <td id="T_57662_row4_col4" class="data row4 col4" >27,425,843.78</td>
#       <td id="T_57662_row4_col5" class="data row4 col5" >5,073,121.02</td>
#       <td id="T_57662_row4_col6" class="data row4 col6" >22,352,722.77</td>
#       <td id="T_57662_row4_col7" class="data row4 col7" >3,017,655.85</td>
#       <td id="T_57662_row4_col8" class="data row4 col8" >24,408,187.93</td>
#     </tr>
#     <tr>
#       <th id="T_57662_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_57662_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_57662_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_57662_row5_col2" class="data row5 col2" >112,069,600.00</td>
#       <td id="T_57662_row5_col3" class="data row5 col3" >84,643,756.22</td>
#       <td id="T_57662_row5_col4" class="data row5 col4" >27,425,843.78</td>
#       <td id="T_57662_row5_col5" class="data row5 col5" >5,073,121.02</td>
#       <td id="T_57662_row5_col6" class="data row5 col6" >22,352,722.77</td>
#       <td id="T_57662_row5_col7" class="data row5 col7" >5,588,180.69</td>
#       <td id="T_57662_row5_col8" class="data row5 col8" >21,837,663.09</td>
#     </tr>
#     <tr>
#       <th id="T_57662_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_57662_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_57662_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_57662_row6_col2" class="data row6 col2" >112,069,600.00</td>
#       <td id="T_57662_row6_col3" class="data row6 col3" >84,643,756.22</td>
#       <td id="T_57662_row6_col4" class="data row6 col4" >27,425,843.78</td>
#       <td id="T_57662_row6_col5" class="data row6 col5" >5,073,121.02</td>
#       <td id="T_57662_row6_col6" class="data row6 col6" >22,352,722.77</td>
#       <td id="T_57662_row6_col7" class="data row6 col7" >5,588,180.69</td>
#       <td id="T_57662_row6_col8" class="data row6 col8" >21,837,663.09</td>
#     </tr>
#     <tr>
#       <th id="T_57662_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_57662_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_57662_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_57662_row7_col2" class="data row7 col2" >112,069,600.00</td>
#       <td id="T_57662_row7_col3" class="data row7 col3" >84,643,756.22</td>
#       <td id="T_57662_row7_col4" class="data row7 col4" >27,425,843.78</td>
#       <td id="T_57662_row7_col5" class="data row7 col5" >5,073,121.02</td>
#       <td id="T_57662_row7_col6" class="data row7 col6" >22,352,722.77</td>
#       <td id="T_57662_row7_col7" class="data row7 col7" >5,588,180.69</td>
#       <td id="T_57662_row7_col8" class="data row7 col8" >21,837,663.09</td>
#     </tr>
#     <tr>
#       <th id="T_57662_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_57662_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_57662_row8_col1" class="data row8 col1" >0.00</td>
#       <td id="T_57662_row8_col2" class="data row8 col2" >112,069,600.00</td>
#       <td id="T_57662_row8_col3" class="data row8 col3" >84,643,756.22</td>
#       <td id="T_57662_row8_col4" class="data row8 col4" >27,425,843.78</td>
#       <td id="T_57662_row8_col5" class="data row8 col5" >5,073,121.02</td>
#       <td id="T_57662_row8_col6" class="data row8 col6" >22,352,722.77</td>
#       <td id="T_57662_row8_col7" class="data row8 col7" >5,588,180.69</td>
#       <td id="T_57662_row8_col8" class="data row8 col8" >21,837,663.09</td>
#     </tr>
#     <tr>
#       <th id="T_57662_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_57662_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_57662_row9_col1" class="data row9 col1" >0.00</td>
#       <td id="T_57662_row9_col2" class="data row9 col2" >112,069,60

# %%
mp_plant.calculate_fixed_capital(print_results=True)   # Calculate the FCI and print the details
mp_plant.calculate_variable_opex(print_results=True)   # Calculate the Variable OPEX and print the details
mp_plant.calculate_revenue(print_results=True)   # Calculate the Revenues and print the details
mp_plant.calculate_levelized_cost(print_results=True)  # Calculate the LCOH and print the details
# Out:
# Capital cost estimation
# ===================================
# ISBL: 40,262,865.21 USD
# OSBL: 16,105,146.08 USD
# Design and engineering: 14,092,002.82 USD
# Contingency: 5,636,801.13 USD
# ===================================
# Fixed capital investment: 76,096,815.24 USD
# Variable production costs estimation
# ===================================
#   - Electricity: 1,646,369.00 USD per year
#   - Methane feed: 39,809,119.20 USD per year
#   - Cooling water: 48,243.38 USD per year
#   - Co$ 2$ tax: 6,464,321.55 USD per year
#   - Carbon disposal fee: 12,691,050.00 USD per year
# ===================================
# Total Variable OPEX: 60,659,103.13USD per year
# Revenue estimation
# ===================================
#   - Hydrogen: 86,687,500.00 USD per year
#   - Solid carbon: 25,382,100.00 USD per year
# ===================================
# Total Revenue: 112,069,600.00 USD per year
# Levelized cost: 4.365 USD/unit

# %% [markdown]
# -------------------------------
# ### Water Electrolysis (WE)
# <p style='text-align: justify'>WE produces H₂ by splitting water into H₂ and oxygen (O₂) using electricity. Alkaline, PEM, and solid oxide electrolyzers vary in efficiency, operational flexibility, and capital cost, but all can deliver zero on-site emissions when powered by renewable electricity. Although widely viewed as a cornerstone of green H₂ production, the economics of electrolysis remain highly sensitive to electricity price, capacity factor, and stack replacement costs. As renewable power becomes cheaper and more abundant, rigorous TEA is essential for understanding the future role of electrolysis in low-carbon energy systems.</p>
#
# <p style='text-align: justify;'>This case study follows the high-pressure (HP) alkaline electrolysis system described in the DOE TEA by Acevedo et al. (4), operating at approximately 30 bar to produce H₂ without downstream compression. Purified water and 30 wt% KOH circulate through zero-gap cells employing nickel-based electrodes and a Zirfon diaphragm, generating H₂ that exits the pressurized cathode manifold. The H₂ purification system consists of a deoxidizer and a dual-bed TSA unit to remove residual oxygen and moisture before delivering 99.99% pure H₂. Electrical conditioning equipment supplies constant current, while gradual voltage degradation is omitted for simplicity.</p>
#
# <p style='text-align: justify;'>The following is the process flow diagram of the pressurized alkaline WE systems:</p>
#
# ![case_study_2-figure_3](img/CS_2-Fig_3.png)
# **<p style='text-align: justify; font-size: 90%;'>Figure 3.** Process flow diagram of a HP alkaline WE system. Makeup water is filtered and deionized before entering the KOH scrubber, where it mixes with recycled water. The pressurized electrolyzer stack receives this KOH solution via the feed pump and generates H₂ and oxygen in electrolyzer cells. Cathode and anode effluent streams are routed to dedicated separators to remove entrained liquid electrolyte, which is recycled. The pressurized H₂ stream enters the purification subsystem, where a deoxygenation reactor removes residual oxygen before a temperature swing adsorption unit dries the gas to product purity. Oxygen from the anode is vented, while purified H₂ exits as the product. Electrical balance-of-plant (BOP) components, including the AC transformer and rectifier, provide the DC power required for stack operation.</p>
#
# <p style='text-align: justify;'>The DOE TEA reports the estimated uninstalled (purchased) capital costs for a high-pressure alkaline WE plant at a 50 TPD capacity projected for 2030. The beginning-of-life power requirement of the system is <b>98 MW (AC input)</b>. These values are adopted here for our comparison study. Table 3 below summarizes the uninstalled capital costs for the stack and the mechanical and electrical balance-of-plant (BOP) components, presented in 2020 cost-year terms:</p>
#
# <center>
# <p style="font-size: 90%;"><b>Table 3.</b> Uninstalled capital costs for the 50-TPD HP alkaline system.</p>
# <span style="font-size: 14px">
#
# | **Uninstalled Capital Costs**| **Price**         |
# |------------------------------|-------------------|
# | Stack Capital Cost           | $17 194 000       |
# | Mechanical BOP               | $11 019 000       |
# | Electrical BOP               | $16 974 000       |
# | **Total**                    | **$45 186 000**   |
#
# </span></center>
#
# <p style='text-align: justify;'>Based on these data, let us create the equipment objects for the HP alkaline system:</p>

# %%
electrolyzer_stack = Equipment('Stack',          0, "Fluids",    "Electrolysis", "Stack",    "Carbon steel", 
                               purchased_cost=17_194_000, cost_year=2020)
mechanical_bop     = Equipment('Mechanical BOP', 0, "Fluids",    "Electrolysis", "Mechanical", "Carbon steel", 
                               purchased_cost=11_019_000, cost_year=2020)
electrical_bop     = Equipment('Electrical BOP', 0, "Electrical","Electrolysis", "Electrical", "Carbon steel", 
                               purchased_cost=16_974_000, cost_year=2020)

# Here, we create the list of the equipment for the water electrolysis process.
we_equipment = [
    electrolyzer_stack,
    mechanical_bop,
    electrical_bop
]

# %% [markdown]
# Here, <b>OpenPyTEA</b> does not use any cost correlations from the database to estimate the equipment purchase costs, as the purchased costs are provided directly when creating the equipment objects. <b>OpenPyTEA</b>, however, escalates the costs to the latest cost year with available CEPCI values in <b>OpenPyTEA</b>. For more details, please refer to: [`walkthrough.ipynb` ](https://github.com/pbtamarona/OpenPyTEA/blob/main/walkthrough.ipynb) and [`cepci_values.csv` ](https://github.com/pbtamarona/OpenPyTEA/blob/main/src/openpytea/data/cepci_values.csv)
#
# We now create the Plant object, considering only electricity and water consumption as variable OPEX.

# %%
# Configuration for the WE plant
config = {
    'plant_name'          : 'Water Electrolysis',
    'process_type'        : 'Fluids',        # Since there are only fluids, we choose 'Fluids'
    'country'             : country,
    'region'              : region,
    'equipment'           : we_equipment,    # This the list of equipment for the WE process
    'interest_rate'       : interest_rate,   # Base economic assumptions
    'project_lifetime'    : project_lifetime,
    'plant_utilization'   : plant_utilization,
    'tax_rate'            : tax_rate,
    'operator_hourly_rate': {
        'rate': operator_rate, 'std': operator_std, 'max': operator_max, 'min': operator_min
    },
    'plant_products': {  # Here we define the products and/or inputs of the plant
        'hydrogen': {
            'production': h2_prod,   # Daily production in kg/day
            'price'     : h2_price,  # Price of hydrogen, in US$/kg
        },
    },
    'variable_opex_inputs': {  # For the variable opex inputs, the consumption is always based on daily consumption
        'electricity': {
            'consumption': (98*1000)*24, # Electricity consumption in kWh/day (this value comes from the DOE report)
            'price': elecs_price, 'std': elecs_std, 'max': elecs_max, 'min': elecs_min
        },
        'water': {
            'consumption': 3.78*2*50_000, # Water consumption in kg/day (this value comes from the DOE report)
            'price': 0.003, 'std': 0.001, 'max': 0.005, 'min': 0
        },
    },
}
we_plant = Plant(config)  # Create the process plant object. Here we name it we_plant.

# %% [markdown]
# <p style="text-align: justify;"> Before proceeding, we need to redefine the number of operators hired. If left unspecified, the default settings estimate operator needs based on the number of fluid and solid processes, which is inaccurate here because we define systems (stack, mechanical, and electrical BOPs) rather than individual process units. We can utilize the <code>calculate_operators_hired</code> function from <code>openpytea.plant</code> object to estimate the number of operators based on process steps. From the process flow diagram, we count 11 fluid processes and 0 solid processes (excluding pumps, phase-separation vessels, and drums), thus: </p>

# %%
# Here, we hardcode the number of fluid and solid processes, instead of letting the Plant object count them automatically
operators_hired = we_plant.calculate_operators_hired(no_fluid_process=11, no_solid_process=0) 
print(f'Estimated # of operators hired for the electrolysis plant: {operators_hired}')
# Out:
# Estimated # of operators hired for the electrolysis plant: 14

# %% [markdown]
# Now, we update the plant configuration with the calculated number of operators hired:

# %%
we_plant.update_configuration({'operators_hired': operators_hired})

# %% [markdown]
# <p style="text-align: justify;"> For electrolyzer technologies, the stack lifetime is typically shorter than the overall plant or project lifetime, so the stack must be replaced during operation. This requires adding the stack purchase cost again in the year(s) when replacement occurs. The DOE assessment report assumes a 10-year stack lifetime. In our case study, the plant operates for 20 years starting in year 3, meaning the stack is replaced in year 13. We include this replacement cost and year using the following plant configuration: </p>

# %%
we_plant.update_configuration({'additional_capex_cost': [electrolyzer_stack.purchased_cost, electrolyzer_stack.purchased_cost], 
                               'additional_capex_years': [10, 20]})
# Let's check this by printing the cash flow table
we_plant.calculate_cash_flow(print_results=True)  # Calculate the cash flow and print the details
# Out:
# <style type="text/css">
# </style>
# <table id="T_4feee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4feee_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_4feee_level0_col1" class="col_heading level0 col1" >Capital cost [USD]</th>
#       <th id="T_4feee_level0_col2" class="col_heading level0 col2" >Revenue [USD]</th>
#       <th id="T_4feee_level0_col3" class="col_heading level0 col3" >Cash cost [USD]</th>
#       <th id="T_4feee_level0_col4" class="col_heading level0 col4" >Gross profit [USD]</th>
#       <th id="T_4feee_level0_col5" class="col_heading level0 col5" >Depreciation [USD]</th>
#       <th id="T_4feee_level0_col6" class="col_heading level0 col6" >Taxable income [USD]</th>
#       <th id="T_4feee_level0_col7" class="col_heading level0 col7" >Tax paid [USD]</th>
#       <th id="T_4feee_level0_col8" class="col_heading level0 col8" >Cash flow [USD]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4feee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4feee_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_4feee_row0_col1" class="data row0 col1" >107,182,162.76</td>
#       <td id="T_4feee_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_4feee_row0_col3" class="data row0 col3" >34,356,350.78</td>
#       <td id="T_4feee_row0_col4" class="data row0 col4" >-34,356,350.78</td>
#       <td id="T_4feee_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_4feee_row0_col6" class="data row0 col6" >-34,356,350.78</td>
#       <td id="T_4feee_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_4feee_row0_col8" class="data row0 col8" >-141,538,513.54</td>
#     </tr>
#     <tr>
#       <th id="T_4feee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4feee_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_4feee_row1_col1" class="data row1 col1" >214,364,325.53</td>
#       <td id="T_4feee_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_4feee_row1_col3" class="data row1 col3" >34,356,350.78</td>
#       <td id="T_4feee_row1_col4" class="data row1 col4" >-34,356,350.78</td>
#       <td id="T_4feee_row1_col5" class="data row1 col5" >0.00</td>
#       <td id="T_4feee_row1_col6" class="data row1 col6" >-34,356,350.78</td>
#       <td id="T_4feee_row1_col7" class="data row1 col7" >0.00</td>
#       <td id="T_4feee_row1_col8" class="data row1 col8" >-248,720,676.31</td>
#     </tr>
#     <tr>
#       <th id="T_4feee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4feee_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_4feee_row2_col1" class="data row2 col1" >89,318,468.97</td>
#       <td id="T_4feee_row2_col2" class="data row2 col2" >34,675,000.00</td>
#       <td id="T_4feee_row2_col3" class="data row2 col3" >50,824,756.58</td>
#       <td id="T_4feee_row2_col4" class="data row2 col4" >-16,149,756.58</td>
#       <td id="T_4feee_row2_col5" class="data row2 col5" >23,818,258.39</td>
#       <td id="T_4feee_row2_col6" class="data row2 col6" >-39,968,014.97</td>
#       <td id="T_4feee_row2_col7" class="data row2 col7" >0.00</td>
#       <td id="T_4feee_row2_col8" class="data row2 col8" >-105,468,225.55</td>
#     </tr>
#     <tr>
#       <th id="T_4feee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4feee_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_4feee_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_4feee_row3_col2" class="data row3 col2" >69,350,000.00</td>
#       <td id="T_4feee_row3_col3" class="data row3 col3" >67,293,162.38</td>
#       <td id="T_4feee_row3_col4" class="data row3 col4" >2,056,837.62</td>
#       <td id="T_4feee_row3_col5" class="data row3 col5" >23,818,258.39</td>
#       <td id="T_4feee_row3_col6" class="data row3 col6" >-21,761,420.77</td>
#       <td id="T_4feee_row3_col7" class="data row3 col7" >0.00</td>
#       <td id="T_4feee_row3_col8" class="data row3 col8" >2,056,837.62</td>
#     </tr>
#     <tr>
#       <th id="T_4feee_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4feee_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_4feee_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_4feee_row4_col2" class="data row4 col2" >86,687,500.00</td>
#       <td id="T_4feee_row4_col3" class="data row4 col3" >75,527,365.28</td>
#       <td id="T_4feee_row4_col4" class="data row4 col4" >11,160,134.72</td>
#       <td id="T_4feee_row4_col5" class="data row4 col5" >23,818,258.39</td>
#       <td id="T_4feee_row4_col6" class="data row4 col6" >-12,658,123.67</td>
#       <td id="T_4feee_row4_col7" class="data row4 col7" >0.00</td>
#       <td id="T_4feee_row4_col8" class="data row4 col8" >11,160,134.72</td>
#     </tr>
#     <tr>
#       <th id="T_4feee_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4feee_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_4feee_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_4feee_row5_col2" class="data row5 col2" >86,687,500.00</td>
#       <td id="T_4feee_row5_col3" class="data row5 col3" >75,527,365.28</td>
#       <td id="T_4feee_row5_col4" class="data row5 col4" >11,160,134.72</td>
#       <td id="T_4feee_row5_col5" class="data row5 col5" >23,818,258.39</td>
#       <td id="T_4feee_row5_col6" class="data row5 col6" >-12,658,123.67</td>
#       <td id="T_4feee_row5_col7" class="data row5 col7" >0.00</td>
#       <td id="T_4feee_row5_col8" class="data row5 col8" >11,160,134.72</td>
#     </tr>
#     <tr>
#       <th id="T_4feee_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4feee_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_4feee_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_4feee_row6_col2" class="data row6 col2" >86,687,500.00</td>
#       <td id="T_4feee_row6_col3" class="data row6 col3" >75,527,365.28</td>
#       <td id="T_4feee_row6_col4" class="data row6 col4" >11,160,134.72</td>
#       <td id="T_4feee_row6_col5" class="data row6 col5" >23,818,258.39</td>
#       <td id="T_4feee_row6_col6" class="data row6 col6" >-12,658,123.67</td>
#       <td id="T_4feee_row6_col7" class="data row6 col7" >0.00</td>
#       <td id="T_4feee_row6_col8" class="data row6 col8" >11,160,134.72</td>
#     </tr>
#     <tr>
#       <th id="T_4feee_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4feee_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_4feee_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_4feee_row7_col2" class="data row7 col2" >86,687,500.00</td>
#       <td id="T_4feee_row7_col3" class="data row7 col3" >75,527,365.28</td>
#       <td id="T_4feee_row7_col4" class="data row7 col4" >11,160,134.72</td>
#       <td id="T_4feee_row7_col5" class="data row7 col5" >23,818,258.39</td>
#       <td id="T_4feee_row7_col6" class="data row7 col6" >-12,658,123.67</td>
#       <td id="T_4feee_row7_col7" class="data row7 col7" >0.00</td>
#       <td id="T_4feee_row7_col8" class="data row7 col8" >11,160,134.72</td>
#     </tr>
#     <tr>
#       <th id="T_4feee_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4feee_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_4feee_row8_col1" class="data row8 col1" >0.00</td>
#       <td id="T_4feee_row8_col2" class="data row8 col2" >86,687,500.00</td>
#       <td id="T_4feee_row8_col3" class="data row8 col3" >75,527,365.28</td>
#       <td id="T_4feee_row8_col4" class="data row8 col4" >11,160,134.72</td>
#       <td id="T_4feee_row8_col5" class="data row8 col5" >23,818,258.39</td>
#       <td id="T_4feee_row8_col6" class="data row8 col6" >-12,658,123.67</td>
#       <td id="T_4feee_row8_col7" class="data row8 col7" >0.00</td>
#       <td id="T_4feee_row8_col8" class="data row8 col8" >11,160,134.72</td>
#     </tr>
#     <tr>
#       <th id="T_4feee_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4feee_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_4feee_row9_col1" class="data row9 col1" >23,071,452.53</td>
#       <td id="T_4feee_row9_col2" class="data row9 col2" >86,687,500.00</td>
#       <td

# %% [markdown]
# Now we can finally calculate the CAPEX, OPEX and LCOH of the WE plant:

# %%
we_plant.calculate_fixed_capital(print_results=True, additional_capex=True)   # Calculate the FCI and print the details, including additional CAPEX
we_plant.calculate_variable_opex(print_results=True)   # Calculate the Variable OPEX and print the details
we_plant.calculate_levelized_cost(print_results=True)  # Calculate the LCOH and print the details
# Out:
# Capital cost estimation
# ===================================
# ISBL: 196,304,327.41 USD
# OSBL: 58,891,298.22 USD
# Design and engineering: 76,558,687.69 USD
# Contingency: 25,519,562.56 USD
# Additional CAPEX: 46,142,905.07 USD
# ===================================
# Fixed capital investment: 403,416,780.95 USD
# Variable production costs estimation
# ===================================
#   - Electricity: 40,777,800.00 USD per year
#   - Water: 393,214.50 USD per year
# ===================================
# Total Variable OPEX: 41,171,014.50USD per year
# Levelized cost: 7.556 USD/unit

# %% [markdown]
# ----------------------------------
#
# ### Techno-economic comparison
#
# To perform the techno-economic analysis, we used the functions in the `analysis.py`module to generate the analysis data and the functions in `plotting.py` for visualization.
#
# First, we compared the CAPEX and OPEX of SMR, MP, and WE using `plot_stacked_bar()`, examining how the cost structures differ across these technologies.

# %%
plants = [we_plant, mp_plant, smr_plant]
plot_stacked_bar(fixed_capital_data(plants, additional_capex=True)) # fixed_capital_data() prepares the data for fixed capital cost breakdown
plot_stacked_bar(variable_opex_data(plants)) # variable_opex_data() prepares the data for variable opex breakdown
plot_stacked_bar(fixed_opex_data(plants)) # fixed_opex_data() prepares the data for fixed opex breakdown
# Out:
# <Axes: ylabel='Annual fixed OPEX / [USD]'>

# %% [markdown]
# For CAPEX, we can also generate a plot for breaking down its direct cost to see which components have significant contribution to the total fixed capital:

# %%
plot_stacked_bar(direct_costs_data(mp_plant)) # direct_costs_data() prepares the data for direct costs breakdown
plot_stacked_bar(direct_costs_data(mp_plant, pct=True)) # pct=True to show the percentage breakdown instead of the absolute values
# Out:
# <Axes: ylabel='Direct costs / [\\%]'>

# %% [markdown]
# <p style="text-align: justify;"> The breakdown plots highlight distinct cost structures across technologies. WE is dominated by high CAPEX, while SMR and MP require substantially lower capital investment. In terms of OPEX, SMR and MP are primarily influenced by feedstock and carbon-related costs, whereas electricity dominates operating costs for WE. </p>
#
# <p style="text-align: justify;"> Next, we generated <b>sensitivity line plots</b> comparing the SMR, MP, and WE plants. Sensitivity analyses were performed to evaluate the effect of key economic parameters across the different pathways. Specifically, the net present value (NPV) was evaluated as a function of the interest rate to compare the sensitivity to financing conditions; the payback time (PBT) was analysed with respect to the methane feed price to assess the impact of fuel cost fluctuations; the LCOH was examined as a function of the solid carbon by-product sales price to quantify potential revenue offsets; and the return on investment (ROI) was evaluated against the electricity price to compare the sensitivity of electricity-intensive pathways.</p>
#
# 1. Sensitivity of NPV to the interest rate:

# %%
plot_sensitivity(sensitivity_data(plants = plants, metric = 'NPV', parameter = 'interest_rate',
                                  plus_minus_value = 1, label=r'Net-present value / [\$]',
                                  n_points = 50)) # n_points is the number of points to be plotted. The more points, the smoother the curve.
# Out:
# <Axes: xlabel='Interest rate / [$\\pm$ \\%]', ylabel='Net-present value / [\\$]'>

# %% [markdown]
# The above plot illustrates the sensitivity of the net present value (NPV) for SMR, MP, and WE as the interest rate varies from −100% to +100% relative to the base value. The results show that the NPV decreases with increasing interest rate for all processes.
#
# 2. Sensitivity of PBT to methane feed price:

# %%
plot_sensitivity(sensitivity_data(plants = plants, metric = 'PBT', parameter = 'methane_feed', 
                                  plus_minus_value = 0.58, label=r'Payback time / [years]',
                                  n_points=100))
# Out:
# <Axes: xlabel='Methane feed price / [$\\pm$ \\%]', ylabel='Payback time / [years]'>

# %% [markdown]
# The plot shows that PBT increases with rising methane feed price for SMR and MP.MP exhibiting the highest sensitivity, while SMR showing moderate sensitivity. Water electrolysis remains unaffected.
#
# 3. Sensitivity of LCOH to MP solid carbon byproduct sales:

# %%
plot_sensitivity(sensitivity_data(plants, 'solid_carbon', 0.8, 
                                  label=r'LCOH / [\$$\cdot$kg$^{-1}_\mathrm{H_2}$]'))
# Out:
# <Axes: xlabel='Solid carbon price / [$\\pm$ \\%]', ylabel='LCOH / [\\$$\\cdot$kg$^{-1}_\\mathrm{H_2}$]'>

# %% [markdown]
# As the carbon by-product sale price increases, the resulting revenue in methane pyrolysis can lower its hydrogen cost to below that of SMR; and even at very low carbon sale prices, the LCOH remains well below that of water electrolysis.
#
# 4. Sensitivity of ROI to electricity price:

# %%
plot_sensitivity(sensitivity_data(plants=plants, parameter='electricity', plus_minus_value=0.55, 
                                  metric='ROI', label=r'Return on investment / [\%]'))
# Out:
# <Axes: xlabel='Electricity price / [$\\pm$ \\%]', ylabel='Return on investment / [\\%]'>

# %% [markdown]
# WE exhibits a strong dependence on electricity price, and the analysis shows that even under very low electricity-cost conditions, WE still gives relatively low ROI compared to SMR and MP.
#
# <p style='text-align: justify;'>While the sensitivity line plots above examine each parameter in isolation, a <b>tornado plot</b> provides a compact, ranked overview of how much each uncertain input shifts the LCOH — all in a single chart. The plot makes it straightforward to identify the dominant cost drivers for each technology. This helps users prioritize high-impact parameters during data collection to improve the reliability of the TEA results.</p>
#
# Below are the tornado plots for the LCOP and NPV of the MP plant:

# %%
plot_tornado(tornado_data(mp_plant, plus_minus_value=0.50, metric='LCOP'))
plot_tornado(tornado_data(mp_plant, plus_minus_value=0.20, metric='NPV'))
# Out:
# <Axes: xlabel='Net present value / [USD]'>

# %% [markdown]
# Having examined the effect of individual parameters on the LCOH for SMR, MP, and WE, we now move to a <b>uncertainty</b> analysis to evaluate how simultaneous fluctuations in inputs influence the overall cost distribution for each technology.
#
# Notice that we have already specified the uncertainties for the labor rate, raw material prices, and utility prices in the begginning. Therefore, all plants are now ready for the <b>Monte Carlo</b> simulations. We can now proceed with the simulations for each hydrogen plant:

# %%
mc_smr = monte_carlo(smr_plant, num_samples=1_000_000, batch_size=10_000)
mc_mp = monte_carlo(mp_plant, num_samples=1_000_000, batch_size=10_000)
# For WE, we set additional_capex=True to include the additional CAPEX in the ROI and PBT analysis
mc_we = monte_carlo(we_plant, num_samples=1_000_000, batch_size=10_000, additional_capex=True)
# Out:
# Monte Carlo: 100%|██████████| 100/100 [03:33<00:00,  2.14s/it]
# Monte Carlo: 100%|██████████| 100/100 [04:02<00:00,  2.42s/it]
# Monte Carlo: 100%|██████████| 100/100 [03:40<00:00,  2.21s/it]

# %% [markdown]
# Below, we present a comparison of the Monte Carlo simulation results for the three H₂ plants:

# %%
plot_multiple_monte_carlo([mc_smr, mc_mp, mc_we], metric = 'LCOP', bins=30, label=r'Levelized cost of hydrogen / [US\$$\cdot$kg$^{-1}_\mathrm{H_2}$]')
# Out:
# <Axes: xlabel='Levelized cost of hydrogen / [US\\$$\\cdot$kg$^{-1}_\\mathrm{H_2}$]', ylabel='Probability density'>

# %% [markdown]
# <p style="text-align: justify;"> The Monte Carlo simulation results reveal distinct cost distributions for the three H₂ production pathways. SMR shows the lowest mean LCOH at approximately 4.04 USD/kg with a relatively narrow spread (σ = 1.16), indicating limited sensitivity to combined parameter uncertainties. MP exhibits a slightly higher mean LCOH of about 4.51 USD/kg with a broader distribution (σ = 1.71), reflecting increased variability driven by factors such as methane price and carbon by-product revenue. WE displays the highest mean LCOH at around 7.71 USD/kg and the widest distribution (σ = 2.10), highlighting its strong dependence on uncertain inputs, particularly electricity price. Overall, the probabilistic analysis reinforces the economic ranking observed in the deterministic results: SMR remains the lowest-cost pathway, followed by MP, while WE consistently yields the highest hydrogen production cost even under favorable conditions. </p>
#
# <p style="text-align: justify;"> This demonstration highlights how <b>OpenPyTEA</b> streamlines and strengthens techno-economic assessment through a transparent and fully reproducible framework. Through consistent plant cost estimation, automated sensitivity analysis, and integrated Monte Carlo evaluation, <b>OpenPyTEA</b> enables efficient exploration of uncertainties, comparison of alternative technologies, and generation of clear insights. These capabilities reduce the barrier to robust TEA and support informed decision-making in hydrogen production and beyond. </p>

# %% [markdown]
# ## References
#
# [1] Acevedo, Y. M.; Prosser, J. H.; Huya-Kouadio, J. M.; McNamara, K. R.; James, B. D. Hydrogen Production Cost with Alkaline Electrolysis; DOE-SA--09629-1; Strategic Analysis, Inc., Arlington VA (United States), 2023. https://doi.org/10.2172/2203367.
#
# [2] Boyano, A.; Blanco-Marigorta, A. M.; Morosuk, T.; Tsatsaronis, G. Exergoenvironmental Analysis of a Steam Methane Reforming Process for Hydrogen Production. Energy 2011, 36 (4), 2202–2214. https://doi.org/10.1016/j.energy.2010.05.020.
#
# [3] Xu, J.; Froment, G. F. Methane Steam Reforming, Methanation and Water-Gas Shift: I. Intrinsic Kinetics. AIChE Journal 1989, 35 (1), 88–96. https://doi.org/10.1002/aic.690350109.
#
# [4] Choi, Y.; Stenger, H. G. Water Gas Shift Reaction Kinetics and Reactor Modeling for Fuel Cell Grade Hydrogen. Journal of Power Sources 2003, 124 (2), 432–439. https://doi.org/10.1016/S0378-7753(03)00614-1.
#
# [5] Keipi, T.; Tolvanen, K. E. S.; Tolvanen, H.; Konttinen, J. Thermo-Catalytic Decomposition of Methane: The Effect of Reaction Parameters on Process Design and the Utilization Possibilities of the Produced Carbon. Energy Conversion and Management 2016, 126, 923–934. https://doi.org/10.1016/j.enconman.2016.08.060.
#
# [6] Keipi, T.; Tolvanen, H.; Konttinen, J. Economic Analysis of Hydrogen Production by Methane Thermal Decomposition: Comparison to Competing Technologies. Energy Conversion and Management 2018, 159, 264–273. https://doi.org/10.1016/j.enconman.2017.12.063.
